# %%
# !pip3 install matplotlib numpy pandas seaborn
# Out:
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (2.2.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from microkit_parser import parse_log_data
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# !pip3 install scipy
# Out:
# Requirement already satisfied: scipy in ./.venv/lib/python3.13/site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in ./.venv/lib/python3.13/site-packages (from scipy) (2.2.4)

# %%
pnk_df = pd.read_csv("junming_branch/pnk_imx.csv")
pnk_df
# Out:
#     Requested_Throughput  Receive_Throughput  Send_Throughput  Packet_Size  \
# 0               10000000            10000184         10000184         1472
# 1               20000000            20000343         20000343         1472
# 2               50000000            50000673         50000673         1472
# 3              100000000           100000724        100000724         1472
# 4              200000000           200002745        199998745         1472
# 5              300000000           300008898        300001398         1472
# 6              400000000           400007692        399999691         1472
# 7              500000000           500004668        499992168         1472
# 8              600000000           600003870        600000870         1472
# 9              700000000           700019072        699994572         1472
# 10             800000000           800006724        800006723         1472
# 11             900000000           900004088        900004088         1472
# 12            1000000000           958342969        999993880         1472
#
#     Minimum_RTT  Average_RTT  Maximum_RTT  Stdev_RTT  Median_RTT  ???  \
# 0            65          132          298      21.45         139    0
# 1            28          138          353      21.38         148    0
# 2            66          127          438      13.64         135    0
# 3            69          200          554     116.40         136    0
# 4            31          236          512     115.00         216    0
# 5            93          302          567     106.87         303    0
# 6           198          397          892      65.18         397    0
# 7           524          734          897      64.60         735    0
# 8           599          718          863      48.02         720    0
# 9           624          731          960      35.62         730    0
# 10          667          727          920      22.29         728    0
# 11          667          740          982      11.18         742    0
# 12         1290         1332         1414       8.43        1333    0
#
#      Idle_Cycles  Total_Cycles
# 0   248429876674  255793079172
# 1   130571606364  138009634061
# 2    58070434381   67533802274
# 3    34023597634   43893316629
# 4    21961710985   32223157742
# 5    17135125620   28273818818
# 6    14955397961   26286465311
# 7    13627571900   25063197610
# 8    12195380880   24286896546
# 9    11075275304   23810780787
# 10    9926850582   23393665578
# 11    8814689744   23065576113
# 12    8103274709   23043373763

# %%
C_df = pd.read_csv("new_results/gcc_imx.csv")
C_df
# Out:
#     Requested_Throughput  Receive_Throughput  Send_Throughput  Packet_Size  \
# 0               10000000            10000184         10000184         1472
# 1               20000000            20000342         20000342         1472
# 2               50000000            50000678         50000678         1472
# 3              100000000           100000919        100000419         1472
# 4              200000000           200003268        199998268         1472
# 5              300000000           300003549        300003549         1472
# 6              400000000           400005349        399997347         1472
# 7              500000000           500019423        499996923         1472
# 8              600000000           599970933        600000930         1472
# 9              700000000           700010698        699996698         1472
# 10             800000000           800009034        800005034         1472
# 11             900000000           900010794        900001794         1472
# 12            1000000000           956834089        999992396         1472
#
#     Minimum_RTT  Average_RTT  Maximum_RTT  Stdev_RTT  Median_RTT  ???  \
# 0            80          133          597      20.05         146    0
# 1            26          143          623      18.17         147    0
# 2            17          135          511      65.83         113    0
# 3            65          159          515      93.73         112    0
# 4            42          206          613     109.81         136    0
# 5            82          260          567     113.84         249    0
# 6           158          370          566      90.54         378    0
# 7           253          463          964      90.27         457    0
# 8           428          677          981      95.78         667    0
# 9           630          769          896      38.92         768    0
# 10          721          784          921      22.87         786    0
# 11          737          791          954      13.19         794    0
# 12         1341         1377         1599      10.10        1379    0
#
#      Idle_Cycles  Total_Cycles
# 0   249015380357  255785859395
# 1   131505525801  138208196591
# 2    59164181495   67537882623
# 3    35030187803   43911026765
# 4    22357895586   32225065631
# 5    16803019055   28292220297
# 6    14258849897   26288010780
# 7    13133848853   25067247623
# 8    11716956055   24287430124
# 9    10687269395   23817790398
# 10    9598266768   23403682571
# 11    8525688587   23070897964
# 12    8024854614   23031447382

# %%
pnk_data = parse_log_data("junming_branch/pnk_imx.txt")
C_data = parse_log_data("new_results/gcc_imx.txt")

# %%
pnk_data
# Out:
# {'configs': ['\x1bMICROKIT_CONFIG_benchmark',
#   'CONFIG_BENCHMARK_TRACK_UTILISATION'],
#  'dhcp': {},
#  'measurements': [],
#  'total_utilisation': [{'KernelUtilisation': 'a1422ec5',
#    'KernelEntries': '38841f',
#    'NumberSchedules': '31ab25',
#    'TotalUtilisation': '3b8e75a0b8'},
#   {'KernelUtilisation': '9e7ff946',
#    'KernelEntries': '376883',
#    'NumberSchedules': '2fd8fc',
#    'TotalUtilisation': '202204f4c2'},
#   {'KernelUtilisation': 'caa24ebd',
#    'KernelEntries': '462485',
#    'NumberSchedules': '3d6cf7',
#    'TotalUtilisation': 'fb9550f8e'},
#   {'KernelUtilisation': 'c701a72d',
#    'KernelEntries': '460eff',
#    'NumberSchedules': '3ae2b8',
#    'TotalUtilisation': 'a383fe5b9'},
#   {'KernelUtilisation': 'b1db364e',
#    'KernelEntries': '3eeb5d',
#    'NumberSchedules': '341368',
#    'TotalUtilisation': '780a7649b'},
#   {'KernelUtilisation': 'aaef25b5',
#    'KernelEntries': '3d6ad3',
#    'NumberSchedules': '3104b4',
#    'TotalUtilisation': '69541423a'},
#   {'KernelUtilisation': '8d6f0e0c',
#    'KernelEntries': '34ac03',
#    'NumberSchedules': '267d39',
#    'TotalUtilisation': '61eccac03'},
#   {'KernelUtilisation': '6920b5bd',
#    'KernelEntries': '266e59',
#    'NumberSchedules': '1becb0',
#    'TotalUtilisation': '5d5e316d8'},
#   {'KernelUtilisation': '5a1392e6',
#    'KernelEntries': '208c88',
#    'NumberSchedules': '174a26',
#    'TotalUtilisation': '5a79db10f'},
#   {'KernelUtilisation': '488f703c',
#    'KernelEntries': '19549c',
#    'NumberSchedules': '127d3a',
#    'TotalUtilisation': '58b3cbc82'},
#   {'KernelUtilisation': '3a1b0abe',
#    'KernelEntries': '138bb0',
#    'NumberSchedules': 'e9f3b',
#    'TotalUtilisation': '572600434'},
#   {'KernelUtilisation': '3074e0c4',
#    'KernelEntries': '109a22',
#    'NumberSchedules': 'beb2c',
#    'TotalUtilisation': '55ed1d458'},
#   {'KernelUtilisation': '30be59c3',
#    'KernelEntries': '10d642',
#    'NumberSchedules': 'c0b92',
#    'TotalUtilisation': '55d7f0cdb'}],
#  'pd_utilisation': {'uart_driver (0)': [{'KernelUtilisation': 'af5',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '67e2'},
#    {'KernelUtilisation': 'a87',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6806'},
#    {'KernelUtilisation': 'd6c',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6bcd'},
#    {'KernelUtilisation': 'b09',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '69bf'},
#    {'KernelUtilisation': 'abc',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6b14'},
#    {'KernelUtilisation': 'dad',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6f7b'},
#    {'KernelUtilisation': '12fb',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '7297'},
#    {'KernelUtilisation': 'bdf',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '69ad'},
#    {'KernelUtilisation': '158a',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '7417'},
#    {'KernelUtilisation': 'be5',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6b45'},
#    {'KernelUtilisation': 'c19',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '6bbf'},
#    {'KernelUtilisation': 'f40',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '70c0'},
#    {'KernelUtilisation': '1290',
#     'KernelEntries': '3',
#     'NumberSchedules': '3',
#     'TotalUtilisation': '7a9a'}],
#   'serial_virt_tx (1)': [{'KernelUtilisation': '1279',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2e78'},
#    {'KernelUtilisation': '1023',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '33db'},
#    {'KernelUtilisation': '10f9',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2c14'},
#    {'KernelUtilisation': 'ee6',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2b44'},
#    {'KernelUtilisation': '1091',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2ce7'},
#    {'KernelUtilisation': 'fcc',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2b7e'},
#    {'KernelUtilisation': '1081',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2c48'},
#    {'KernelUtilisation': 'fae',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2b8b'},
#    {'KernelUtilisation': '127d',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2d8e'},
#    {'KernelUtilisation': 'f8d',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2bd5'},
#    {'KernelUtilisation': '10d2',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2cfa'},
#    {'KernelUtilisation': '1118',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2cdc'},
#    {'KernelUtilisation': '10b6',
#     'KernelEntries': '2',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '2d2f'}],
#   'ethernet_driver (2)': [{'KernelUtilisation': '2bda315c',
#     'KernelEntries': 'e9f9d',
#     'NumberSchedules': 'e7865',
#     'TotalUtilisation': '9cf448de'},
#    {'KernelUtilisation': '2d7a548c',
#     'KernelEntries': 'f5597',
#     'NumberSchedules': 'f0de0',
#     'TotalUtilisation': 'a5765460'},
#    {'KernelUtilisation': '3a4b8018',
#     'KernelEntries': '13567e',
#     'NumberSchedules': '13565b',
#     'TotalUtilisation': 'd02bc2fc'},
#    {'KernelUtilisation': '39297eb6',
#     'KernelEntries': '13bf22',
#     'NumberSchedules': '120a23',
#     'TotalUtilisation': 'd79195c6'},
#    {'KernelUtilisation': '318d65a5',
#     'KernelEntries': '10d92c',
#     'NumberSchedules': 'fa99d',
#     'TotalUtilisation': 'da0c4514'},
#    {'KernelUtilisation': '2f8ff609',
#     'KernelEntries': '107856',
#     'NumberSchedules': 'eaed3',
#     'TotalUtilisation': 'eeb141f2'},
#    {'KernelUtilisation': '2c591aa6',
#     'KernelEntries': '105b50',
#     'NumberSchedules': 'ceadc',
#     'TotalUtilisation': 'fe600120'},
#    {'KernelUtilisation': '22b27920',
#     'KernelEntries': 'c0705',
#     'NumberSchedules': '9fbfb',
#     'TotalUtilisation': '103c7cb93'},
#    {'KernelUtilisation': '1dd054b9',
#     'KernelEntries': 'aa99a',
#     'NumberSchedules': '8569d',
#     'TotalUtilisation': '10a77a8f4'},
#    {'KernelUtilisation': '15ccf6cf',
#     'KernelEntries': '8074f',
#     'NumberSchedules': '5be08',
#     'TotalUtilisation': '110784844'},
#    {'KernelUtilisation': '114fc3b4',
#     'KernelEntries': '6f86d',
#     'NumberSchedules': '44fe0',
#     'TotalUtilisation': '11cd84862'},
#    {'KernelUtilisation': 'dd0a65d',
#     'KernelEntries': '5da3a',
#     'NumberSchedules': '30e11',
#     'TotalUtilisation': '1245fd841'},
#    {'KernelUtilisation': 'd953e87',
#     'KernelEntries': '5c642',
#     'NumberSchedules': '2ff95',
#     'TotalUtilisation': '131b31b33'}],
#   'net_virt_tx (3)': [{'KernelUtilisation': '155c1aca',
#     'KernelEntries': '5a758',
#     'NumberSchedules': '5a758',
#     'TotalUtilisation': '2f60c4c4'},
#    {'KernelUtilisation': '1616aeee',
#     'KernelEntries': '5bc18',
#     'NumberSchedules': '5bc18',
#     'TotalUtilisation': '306c6bed'},
#    {'KernelUtilisation': '1d123381',
#     'KernelEntries': '7af52',
#     'NumberSchedules': '7af52',
#     'TotalUtilisation': '400bf708'},
#    {'KernelUtilisation': '1bd260d5',
#     'KernelEntries': '735a9',
#     'NumberSchedules': '735a6',
#     'TotalUtilisation': '400320ef'},
#    {'KernelUtilisation': '1558401e',
#     'KernelEntries': '57b63',
#     'NumberSchedules': '57b32',
#     'TotalUtilisation': '3ab0b4f3'},
#    {'KernelUtilisation': '125da866',
#     'KernelEntries': '49e97',
#     'NumberSchedules': '495a4',
#     'TotalUtilisation': '3a5d8bb0'},
#    {'KernelUtilisation': '1088654f',
#     'KernelEntries': '3f7c2',
#     'NumberSchedules': '3f68f',
#     'TotalUtilisation': '3b8e1d53'},
#    {'KernelUtilisation': '8a42b20',
#     'KernelEntries': '29a95',
#     'NumberSchedules': '1f7c6',
#     'TotalUtilisation': '35fa36dc'},
#    {'KernelUtilisation': '8c61044',
#     'KernelEntries': '1f2c3',
#     'NumberSchedules': '1f2a5',
#     'TotalUtilisation': '3ccd9560'},
#    {'KernelUtilisation': '8c2532a',
#     'KernelEntries': '1fa54',
#     'NumberSchedules': '1fa52',
#     'TotalUtilisation': '440bcccd'},
#    {'KernelUtilisation': 'a323152',
#     'KernelEntries': '255a2',
#     'NumberSchedules': '23b82',
#     'TotalUtilisation': '4e063fef'},
#    {'KernelUtilisation': '85b9195',
#     'KernelEntries': '1e6d6',
#     'NumberSchedules': '1e6c7',
#     'TotalUtilisation': '529c8715'},
#    {'KernelUtilisation': '826e78f',
#     'KernelEntries': '1eec9',
#     'NumberSchedules': '1eea9',
#     'TotalUtilisation': '528e85fa'}],
#   'net_virt_rx (4)': [{'KernelUtilisation': '26450ea1',
#     'KernelEntries': 'd291c',
#     'NumberSchedules': '9d46f',
#     'TotalUtilisation': '4a983e90'},
#    {'KernelUtilisation': '27315871',
#     'KernelEntries': 'da92d',
#     'NumberSchedules': '9fab1',
#     'TotalUtilisation': '4d071c9d'},
#    {'KernelUtilisation': '32649236',
#     'KernelEntries': '1174e5',
#     'NumberSchedules': 'd1bed',
#     'TotalUtilisation': '62b0ab15'},
#    {'KernelUtilisation': '34284b66',
#     'KernelEntries': '126f28',
#     'NumberSchedules': 'daab7',
#     'TotalUtilisation': '68518ec8'},
#    {'KernelUtilisation': '346826a1',
#     'KernelEntries': '124f85',
#     'NumberSchedules': 'd6f01',
#     'TotalUtilisation': '6c49dc5a'},
#    {'KernelUtilisation': '376c9569',
#     'KernelEntries': '13657e',
#     'NumberSchedules': 'e002d',
#     'TotalUtilisation': '74406b3a'},
#    {'KernelUtilisation': '2c7903bf',
#     'KernelEntries': '1041bd',
#     'NumberSchedules': 'aae97',
#     'TotalUtilisation': '68df3dae'},
#    {'KernelUtilisation': '22a898f7',
#     'KernelEntries': 'c15a5',
#     'NumberSchedules': '801b4',
#     'TotalUtilisation': '5a4eb237'},
#    {'KernelUtilisation': '1c28d245',
#     'KernelEntries': 'a207c',
#     'NumberSchedules': '675fc',
#     'TotalUtilisation': '553cdff2'},
#    {'KernelUtilisation': '1625ccda',
#     'KernelEntries': '7dc6c',
#     'NumberSchedules': '55716',
#     'TotalUtilisation': '50aa3179'},
#    {'KernelUtilisation': 'f81e3ae',
#     'KernelEntries': '5270c',
#     'NumberSchedules': '40770',
#     'TotalUtilisation': '4c953e9c'},
#    {'KernelUtilisation': 'bbf91c6',
#     'KernelEntries': '3f8f8',
#     'NumberSchedules': '309e8',
#     'TotalUtilisation': '4ee18658'},
#    {'KernelUtilisation': 'bb0a3fc',
#     'KernelEntries': '3fce6',
#     'NumberSchedules': '2fdf3',
#     'TotalUtilisation': '51242df9'}],
#   'client0 (5)': [{'KernelUtilisation': '7e6abc3',
#     'KernelEntries': '36826',
#     'NumberSchedules': '367dd',
#     'TotalUtilisation': '3435980e'},
#    {'KernelUtilisation': '765f8ab',
#     'KernelEntries': '328ff',
#     'NumberSchedules': '328ae',
#     'TotalUtilisation': '343211e7'},
#    {'KernelUtilisation': 'a41b5ec',
#     'KernelEntries': '463f9',
#     'NumberSchedules': '4634b',
#     'TotalUtilisation': '447565dc'},
#    {'KernelUtilisation': 'a6f0ed3',
#     'KernelEntries': '466ea',
#     'NumberSchedules': '4662d',
#     'TotalUtilisation': '4edb9dba'},
#    {'KernelUtilisation': '9e15860',
#     'KernelEntries': '421fa',
#     'NumberSchedules': '4216d',
#     'TotalUtilisation': '60ff4c39'},
#    {'KernelUtilisation': 'a06d8da',
#     'KernelEntries': '422fb',
#     'NumberSchedules': '4226b',
#     'TotalUtilisation': '72c5fcd0'},
#    {'KernelUtilisation': '5da34bb',
#     'KernelEntries': '258e9',
#     'NumberSchedules': '2566d',
#     'TotalUtilisation': '7b761b5a'},
#    {'KernelUtilisation': '58ea1fa',
#     'KernelEntries': '1f143',
#     'NumberSchedules': '1f0ef',
#     'TotalUtilisation': '8df6b41c'},
#    {'KernelUtilisation': '2738473',
#     'KernelEntries': 'ed77',
#     'NumberSchedules': 'ed15',
#     'TotalUtilisation': '9f04a7f9'},
#    {'KernelUtilisation': '2691e3c',
#     'KernelEntries': 'e8ab',
#     'NumberSchedules': 'e83d',
#     'TotalUtilisation': 'b2f7ad4c'},
#    {'KernelUtilisation': '28cb3c7',
#     'KernelEntries': 'f16b',
#     'NumberSchedules': 'f0d1',
#     'TotalUtilisation': 'c94a9049'},
#    {'KernelUtilisation': '2929a33',
#     'KernelEntries': 'f349',
#     'NumberSchedules': 'f2b4',
#     'TotalUtilisation': 'dc39e48c'},
#    {'KernelUtilisation': '2b66ac2',
#     'KernelEntries': '10210',
#     'NumberSchedules': '10126',
#     'TotalUtilisation': 'e9610a34'}],
#   'client0_net_copier (6)': [{'KernelUtilisation': '1530a6ee',
#     'KernelEntries': '9db50',
#     'NumberSchedules': '68b4d',
#     'TotalUtilisation': '400b3746'},
#    {'KernelUtilisation': '1580ab05',
#     'KernelEntries': 'a311e',
#     'NumberSchedules': '69f19',
#     'TotalUtilisation': '41f3bbfc'},
#    {'KernelUtilisation': '1c1a1482',
#     'KernelEntries': 'd0b87',
#     'NumberSchedules': '8b1e5',
#     'TotalUtilisation': '54ff9e4d'},
#    {'KernelUtilisation': '1da1f150',
#     'KernelEntries': 'daf8c',
#     'NumberSchedules': '903ba',
#     'TotalUtilisation': '5cbbdb0e'},
#    {'KernelUtilisation': '1c510fd0',
#     'KernelEntries': 'd3273',
#     'NumberSchedules': '88b48',
#     'TotalUtilisation': '68c4e2aa'},
#    {'KernelUtilisation': '1bbc6504',
#     'KernelEntries': 'd4b39',
#     'NumberSchedules': '83def',
#     'TotalUtilisation': '75c7fb3d'},
#    {'KernelUtilisation': '18df4e3e',
#     'KernelEntries': 'c424c',
#     'NumberSchedules': '72b2a',
#     'TotalUtilisation': '7ccf6a00'},
#    {'KernelUtilisation': '1141853a',
#     'KernelEntries': '8aa65',
#     'NumberSchedules': '4ed39',
#     'TotalUtilisation': '80c9615b'},
#    {'KernelUtilisation': '10546744',
#     'KernelEntries': '7c5a2',
#     'NumberSchedules': '483b5',
#     'TotalUtilisation': '8e1bb7da'},
#    {'KernelUtilisation': 'ce20700',
#     'KernelEntries': '57104',
#     'NumberSchedules': '36ba0',
#     'TotalUtilisation': '97cd6519'},
#    {'KernelUtilisation': '7e657e1',
#     'KernelEntries': '30958',
#     'NumberSchedules': '202f6',
#     'TotalUtilisation': '9aa0817e'},
#    {'KernelUtilisation': '7587509',
#     'KernelEntries': '2cda0',
#     'NumberSchedules': '1ddf0',
#     'TotalUtilisation': 'a7f7c211'},
#    {'KernelUtilisation': '7d30b2f',
#     'KernelEntries': '2fa19',
#     'NumberSchedules': '1fa88',
#     'TotalUtilisation': 'b4295191'}],
#   'client1 (7)': [{'KernelUtilisation': '550a46',
#     'KernelEntries': '24ae',
#     'NumberSchedules': '24ac',
#     'TotalUtilisation': 'd740ff'},
#    {'KernelUtilisation': '36c3d4',
#     'KernelEntries': '13da',
#     'NumberSchedules': '13da',
#     'TotalUtilisation': '97024e'},
#    {'KernelUtilisation': '22f1c5',
#     'KernelEntries': 'a03',
#     'NumberSchedules': 'a01',
#     'TotalUtilisation': '731198'},
#    {'KernelUtilisation': '16e090',
#     'KernelEntries': '69c',
#     'NumberSchedules': '69a',
#     'TotalUtilisation': '548941'},
#    {'KernelUtilisation': '11200c',
#     'KernelEntries': '4ce',
#     'NumberSchedules': '4ce',
#     'TotalUtilisation': '3e63c2'},
#    {'KernelUtilisation': 'ec42a',
#     'KernelEntries': '439',
#     'NumberSchedules': '439',
#     'TotalUtilisation': '36e6ba'},
#    {'KernelUtilisation': 'f042a',
#     'KernelEntries': '3e6',
#     'NumberSchedules': '3e3',
#     'TotalUtilisation': '35ccba'},
#    {'KernelUtilisation': 'af130',
#     'KernelEntries': '383',
#     'NumberSchedules': '383',
#     'TotalUtilisation': '2e03be'},
#    {'KernelUtilisation': 'b0f38',
#     'KernelEntries': '36f',
#     'NumberSchedules': '36f',
#     'TotalUtilisation': '2cc858'},
#    {'KernelUtilisation': 'cccb9',
#     'KernelEntries': '34e',
#     'NumberSchedules': '34e',
#     'TotalUtilisation': '2de300'},
#    {'KernelUtilisation': 'd9c9e',
#     'KernelEntries': '346',
#     'NumberSchedules': '346',
#     'TotalUtilisation': '2fc2bc'},
#    {'KernelUtilisation': 'b3d74',
#     'KernelEntries': '334',
#     'NumberSchedules': '334',
#     'TotalUtilisation': '2bf94a'},
#    {'KernelUtilisation': 'd6f38',
#     'KernelEntries': '333',
#     'NumberSchedules': '333',
#     'TotalUtilisation': '2f040a'}],
#   'client1_net_copier (8)': [{'KernelUtilisation': '3189',
#     'KernelEntries': '12',
#     'NumberSchedules': 'c',
#     'TotalUtilisation': '7f5c'},
#    {'KernelUtilisation': '1748',
#     'KernelEntries': '6',
#     'NumberSchedules': '4',
#     'TotalUtilisation': '4342'},
#    {'KernelUtilisation': '1dd3',
#     'KernelEntries': '9',
#     'NumberSchedules': '6',
#     'TotalUtilisation': '5445'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': 'e58',
#     'KernelEntries': '3',
#     'NumberSchedules': '2',
#     'TotalUtilisation': '247a'},
#    {'KernelUtilisation': '3335',
#     'KernelEntries': '11',
#     'NumberSchedules': 'c',
#     'TotalUtilisation': '75c4'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': '11b9',
#     'KernelEntries': '5',
#     'NumberSchedules': '3',
#     'TotalUtilisation': '2a7e'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'},
#    {'KernelUtilisation': '0',
#     'KernelEntries': '0',
#     'NumberSchedules': '0',
#     'TotalUtilisation': '0'}],
#   'timer_driver (9)': [{'KernelUtilisation': 'e8f657',
#     'KernelEntries': '6b61',
#     'NumberSchedules': '5ea7',
#     'TotalUtilisation': '3d938d1'},
#    {'KernelUtilisation': '815327',
#     'KernelEntries': '3a5e',
#     'NumberSchedules': '3369',
#     'TotalUtilisation': '2284bd5'},
#    {'KernelUtilisation': '712b81',
#     'KernelEntries': '1cfe',
#     'NumberSchedules': '18e9',
#     'TotalUtilisation': '149853d'},
#    {'KernelUtilisation': '506a8c',
#     'KernelEntries': '13ec',
#     'NumberSchedules': '10a5',
#     'TotalUtilisation': 'edbb8d'},
#    {'KernelUtilisation': '3a0dc8',
#     'KernelEntries': 'ed7',
#     'NumberSchedules': 'c27',
#     'TotalUtilisation': 'ada9c4'},
#    {'KernelUtilisation': '345c41',
#     'KernelEntries': 'd5b',
#     'NumberSchedules': 'ac0',
#     'TotalUtilisation': '9b88c2'},
#    {'KernelUtilisation': '30041f',
#     'KernelEntries': 'ca7',
#     'NumberSchedules': 'a09',
#     'TotalUtilisation': '90208e'},
#    {'KernelUtilisation': '3090cc',
#     'KernelEntries': 'bde',
#     'NumberSchedules': '986',
#     'TotalUtilisation': '900868'},
#    {'KernelUtilisation': '2efd0a',
#     'KernelEntries': 'bb2',
#     'NumberSchedules': '943',
#     'TotalUtilisation': '8b773b'},
#    {'KernelUtilisation': '34ae3d',
#     'KernelEntries': 'c12',
#     'NumberSchedules': '928',
#     'TotalUtilisation': '99ab80'},
#    {'KernelUtilisation': '37f7ed',
#     'KernelEntries': 'c34',
#     'NumberSchedules': '90b',
#     'TotalUtilisation': 'a3c00a'},
#    {'KernelUtilisation': '35cca4',
#     'KernelEntries': 'c08',
#     'NumberSchedules': '8a7',
#     'TotalUtilisation': 'a3068c'},
#    {'KernelUtilisation': '3452af',
#     'KernelEntries': 'bf8',
#     'NumberSchedules': '897',
#     'TotalUtilisation': 'a39403'}]}}

# %%
fig, ax1 = plt.subplots(figsize=(10, 6), dpi=300)

pnk_color = '#1A5FB4'
C_color = '#C01C28'

ax1.grid(True, linestyle='--', alpha=0.3, which='both')
ax1.set_axisbelow(True)

# Convert throughput to Mbps
pnk_req_mbps = pnk_df['Requested_Throughput'] / 1e6
pnk_recv_mbps = pnk_df['Receive_Throughput'] / 1e6
C_req_mbps = C_df['Requested_Throughput'] / 1e6
C_recv_mbps = C_df['Receive_Throughput'] / 1e6

line1, = ax1.plot(pnk_req_mbps, pnk_recv_mbps,
                 marker='o', markersize=7, linestyle='-', linewidth=2, 
                 color=pnk_color, label='pnk Throughput')

line2, = ax1.plot(C_req_mbps, C_recv_mbps,
                 marker='o', markersize=7, linestyle='-', linewidth=2, 
                 color=C_color, label='C Throughput')

ax1.set_xlabel('Requested Throughput (Mbps)', fontsize=11)
ax1.set_ylabel('Achieved Throughput (Mbps)', fontsize=11)


ax2 = ax1.twinx()

pnk_cpu_util = [(pnk_df['Total_Cycles'][i] - pnk_df['Idle_Cycles'][i]) / pnk_df['Total_Cycles'][i]
                for i in range(len(pnk_df))]
C_cpu_util = [(C_df['Total_Cycles'][i] - C_df['Idle_Cycles'][i]) / C_df['Total_Cycles'][i]
                for i in range(len(C_df))]

line3, = ax2.plot(pnk_req_mbps, [100 * u for u in pnk_cpu_util],
                 marker='s', markersize=6, linestyle='--', linewidth=2, 
                 color=pnk_color, alpha=0.8, label='pnk CPU Util (%)')

line4, = ax2.plot(C_req_mbps, [100 * u for u in C_cpu_util],
                 marker='s', markersize=6, linestyle='--', linewidth=2, 
                 color=C_color, alpha=0.8, label='C CPU Util (%)')

max_throughput = max(max(pnk_recv_mbps), max(C_recv_mbps))
max_cpu_util = max(max([100 * u for u in pnk_cpu_util]), max([100 * u for u in C_cpu_util]))

ax1.set_ylim(0, 1.1 * max_throughput)
ax2.set_ylim(0, max(110, 1.2 * max_cpu_util))

ax2.set_ylabel('CPU Utilisation (%)', fontsize=11)
ax1.set_xticks(pnk_req_mbps)

lines = [line1, line2, line3, line4]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left', fontsize=10, frameon=True, 
           framealpha=0.9, edgecolor='gray', borderaxespad=1.2)

ax1.set_title('Networking Performance (Meson): Pancake vs C', 
              fontsize=14, fontweight='bold', pad=15)

ax1.set_xticks(np.linspace(min(pnk_req_mbps), max(pnk_req_mbps), len(pnk_req_mbps)))

xlabels = [f'{int(x)}' for x in pnk_req_mbps]
ax1.set_xticklabels(xlabels, fontsize=9)

diff_points = [pnk_cpu_util[i] - C_cpu_util[i] for i in range(len(pnk_cpu_util))]
max_diff_idx = np.argmax(np.abs(diff_points))
max_diff_x = pnk_req_mbps[max_diff_idx]
pnk_val = pnk_cpu_util[max_diff_idx] * 100
C_val = C_cpu_util[max_diff_idx] * 100

max_diff_absolute = pnk_val - C_val
max_diff_relative = (abs(max_diff_absolute) / C_val) * 100 if C_val != 0 else 0

is_pnk_better = max_diff_absolute < 0
box_color = 'green' if is_pnk_better else 'red'
arrow_symbol = '↓' if is_pnk_better else '↑'

annotation_text = f'Max diff: {arrow_symbol} {abs(max_diff_absolute):.1f}% ({abs(max_diff_relative):.1f}% rel.)'
ax2.annotate(annotation_text, 
            xy=(max_diff_x, max(pnk_val, C_val)),
            xytext=(10, 15), textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color=box_color, lw=1.5),
            bbox=dict(boxstyle='round,pad=0.3', fc='white', ec=box_color, alpha=0.8),
            fontsize=9,
            color=box_color)

relative_diff = ((np.array(pnk_cpu_util) - np.array(C_cpu_util)) / np.array(C_cpu_util)) * 100
avg_improvement = np.mean(relative_diff)
avg_absolute_diff = np.mean(np.array(pnk_cpu_util) - np.array(C_cpu_util)) * 100

is_avg_pnk_better = avg_absolute_diff < 0
avg_box_color = 'green' if is_avg_pnk_better else 'red'
avg_arrow_symbol = '↓' if is_avg_pnk_better else '↑'

avg_props = dict(boxstyle='round', facecolor='white', alpha=0.8, edgecolor=avg_box_color)
avg_textstr = f'Avg diff: {avg_arrow_symbol} {abs(avg_absolute_diff):.1f}% ({abs(avg_improvement):.1f}% rel.)'
ax2.text(0.98, 0.98, avg_textstr, transform=ax2.transAxes, fontsize=9,
         verticalalignment='top', horizontalalignment='right', bbox=avg_props,
         color=avg_box_color)

plt.tight_layout()
plt.savefig('network_perf_imx_pnk_vs_c.svg', dpi=300, bbox_inches='tight')
plt.show()

print(f"Average relative difference in CPU utilization: {avg_improvement:.2f}%")
# Out:
# Average relative difference in CPU utilization: 1.80%

# %%
test = {pd_name: [int(m['TotalUtilisation'], 16) for m in measurements] for pd_name, measurements in pnk_data['pd_utilisation'].items()}

# %%
from plotter import UtilizationVisualizer

x_labels = ["10", "20", "50", "100", "200", "300", "400", "500", "600", "700", "800", "900", "1000"]
visualizer = UtilizationVisualizer(pnk_data, C_data, name_a="Pancake", name_b="C", x_tick_labels=x_labels)



visualizer.print_available_pds()
visualizer.plot_specific_pd('ethernet_driver (2)', figsize=(10, 6), dpi=300, save_path="imx_pnk_vs_c_ethernet_driver_cycles.png", driver_name="i.MX", use_percent=True)
# Out:
# Available PD IDs:
#   - uart_driver (0)
#   - timer_driver (9)
#   - serial_virt_tx (1)
#   - net_virt_tx (3)
#   - net_virt_rx (4)
#   - ethernet_driver (2)
#   - client1_net_copier (8)
#   - client1 (7)
#   - client0_net_copier (6)
#   - client0 (5)
# Iteration 1: ethernet_driver (2) - Pancake: 1.0294471121877902, C: 0.8113758757839389
# Iteration 2: ethernet_driver (2) - Pancake: 2.011449496104808, C: 1.4862218761316746
# Iteration 3: ethernet_driver (2) - Pancake: 5.171522003277323, C: 3.9138298217849097
# Iteration 4: ethernet_driver (2) - Pancake: 8.239607248881258, C: 5.9199866552906855
# Iteration 5: ethernet_driver (2) - Pancake: 11.352796641167554, C: 8.928546636641062
# Iteration 6: ethernet_driver (2) - Pancake: 14.163579059639714, C: 11.580024498273964
# Iteration 7: ethernet_driver (2) - Pancake: 16.235326678134676, C: 13.112170916407461
# Iteration 8: ethernet_driver (2) - Pancake: 17.38956415979001, C: 14.044567645385268
# Iteration 9: ethernet_driver (2) - Pancake: 18.40732797292889, C: 15.635159997233947
# Iteration 10: ethernet_driver (2) - Pancake: 19.19833011830614, C: 16.761665791019322
# Iteration 11: ethernet_driver (2) - Pancake: 20.42813743595259, C: 17.528623928065254
# Iteration 12: ethernet_driver (2) - Pancake: 21.266381688475054, C: 18.050016146484694
# Iteration 13: ethernet_driver (2) - Pancake: 22.25704110183078, C: 18.479315456762237
# [np.float64(26.876721740482388), np.float64(35.33978529102206), np.float64(32.13456483191802), np.float64(39.18286862213668), np.float64(27.151675442650763), np.float64(22.31044124086988), np.float64(23.818754206591088), np.float64(23.817013089070297), np.float64(17.730346067359555), np.float64(14.537125114332902), np.float64(16.541592310876695), np.float64(17.81918373860712), np.float64(20.442995596387956)]

# %%
visualizer.set_pds_to_visualize(['net_virt_tx (3)', 'net_virt_rx (4)', 'ethernet_driver (2)', 'client0_net_copier (6)', 'client0 (5)'])
visualizer.plot_all(figsize=(10, 6), dpi=300, save_path="imx_pnk_vs_c_all_pds.svg", driver_name="i.MX")
